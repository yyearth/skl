# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fn = np.load('../skyline-master-original/data/four_negative.npy')
fn
# Out:
# array([[0.31125686, 0.21999803, 0.71886654, 0.63592717],
#        [0.15085758, 0.05335352, 0.6474244 , 0.64064131],
#        [0.19833096, 0.16830987, 0.69326923, 0.69979224],
#        ...,
#        [0.39407613, 0.13457899, 0.70376362, 0.64669788],
#        [0.15768358, 0.06778439, 0.65761191, 0.67228028],
#        [0.14680084, 0.08206956, 0.52604596, 0.71603967]])

# %%
nc = np.load('../skyline-master-original/data/Negative_correlation.npy')
nc
# Out:
# array([[-3.07004084e-01,  5.61542067e+01],
#        [ 2.50846189e+00, -1.84861330e+02],
#        [ 8.20930750e-01, -5.41560152e+01],
#        ...,
#        [-4.95465777e-01,  3.46695553e+01],
#        [-1.78051430e-01,  4.13624828e+01],
#        [ 1.85485995e+00, -1.64619502e+02]])

# %%
plt.scatter(nc[:, 0], nc[:, 1])
plt.show()

# %%
ic = np.load('./skyline-master-original/data/Incorrelation.npy')
print(ic.shape)
ic
# Out:
# (30000, 2)
# array([[ 1.94994121,  0.63609473],
#        [-9.20154419, -4.56826876],
#        [-3.05562744,  2.05006882],
#        ...,
#        [ 2.77963603, -0.2103757 ],
#        [ 2.66384024,  0.67231003],
#        [-8.45986545, -4.57201396]])

# %%
plt.scatter(ic[:, 0], ic[:, 1])
plt.show()

# %%
ics = np.load('../skyline-master-original/data/Incorrelation_skyline.npy')
ics
# Out:
# array([[ 8.64000000e+03, -1.11898711e+01, -8.68915730e+00],
#        [ 1.42900000e+04, -1.40338398e+01, -5.75016987e+00],
#        [ 2.01470000e+04, -1.12448774e+01, -8.09153704e+00],
#        [ 9.01100000e+03, -1.13308173e+01, -7.86786924e+00],
#        [ 2.95610000e+04, -9.81208347e+00, -9.31954895e+00],
#        [ 2.41900000e+04, -1.22395856e+01, -6.85988065e+00],
#        [ 2.27220000e+04, -9.98872415e+00, -8.81224501e+00],
#        [ 1.35290000e+04, -1.14834852e+01, -7.03673732e+00],
#        [ 1.58660000e+04, -1.25947504e+01, -5.87662775e+00],
#        [ 2.39930000e+04, -1.24247439e+01, -5.92071789e+00],
#        [ 1.63640000e+04, -1.42586049e+01, -3.97019099e+00],
#        [ 1.75400000e+04, -2.85094436e+00, -1.00656263e+01]])

# %%
plt.scatter(ics[:, 1], ics[:, 2])
plt.show()

# %%
ps = np.load('../skyline-master-original/data/positive_skyline.npy')
print(ps.shape)
# Out:
# (1, 3)

# %%
pc = np.load('../skyline-master-original/data/Positive_correlation.npy')
print(pc.shape)
pc
# Out:
# (30000, 2)
# array([[ -0.28262511,  -1.30906595],
#        [ -0.71051679, -10.49697786],
#        [  0.39694618,   9.82120759],
#        ...,
#        [  0.78038259,  18.77704311],
#        [ -1.11105179, -18.89111841],
#        [  0.74608846,  15.86435759]])

# %%
plt.scatter(pc[:, 0], pc[:, 1])
plt.show()

# %%
who
# Out:
# fn	 ic	 ics	 nc	 np	 pc	 plt	 ps

# %%
# %matplotlib inline
fig, ax = plt.subplots(3, 1, sharex=True)
plt.figure(dpi=360, figsize=(5, 17))
titles = ['Incorrelation', 'positive', 'negative']
for i, d in enumerate([ic, pc, nc]):
    ax[i].scatter(d[:,0], d[:,1])
    ax[i].set_title(titles[i])
    

plt.show()

# %% [markdown]
# linear scale range to [-5 +5]

# %%
range_ = [-5, 5]
newdata = []
for i, d in enumerate([ic, pc, nc]):
    maxmin = np.ceil(np.max(d, axis=0))-np.floor(np.min(d, axis=0))
    fac = np.divide(np.array([10, 10]), maxmin)
    l = np.full((d.shape[0], 1), fac[0])
    r = np.full((d.shape[0], 1), fac[1])
    facm = np.concatenate((l, r), axis=1)

    med = np.median(d, axis=0)
    l = np.full((d.shape[0], 1), med[0])
    r = np.full((d.shape[0], 1), med[1])
    medm = np.concatenate((l, r), axis=1)
    new = np.multiply(np.subtract(d, medm), facm)
    # np.median(new, axis=0)
    newdata.append(new)
    
ic, pc, nc = newdata

# %%
np.max(nc, axis=0)
# Out:
# array([4.74917949, 4.31253841])

# %%
np.median(nc, axis=0)
# Out:
# array([0., 0.])

# %%
np.min(nc, axis=0)
# Out:
# array([-4.34172961, -4.77837068])

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/yangyou/Desktop/repos/skyline-master-original'

# %%
np.savetxt('/Users/yangyou/Desktop/Incorrelation.csv', ic, header='shape:(30000, 2) range:[-5, +5]', delimiter=',', )

# %%
np.savetxt('/Users/yangyou/Desktop/negative.csv', nc, header='shape:(30000, 2) range:[-5, +5]', delimiter=',', )

# %%
np.savetxt('/Users/yangyou/Desktop/positive.csv', pc, header='shape:(30000, 2) range:[-5, +5]', delimiter=',', )
